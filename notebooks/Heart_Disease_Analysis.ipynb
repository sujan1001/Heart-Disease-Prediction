# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/Cardiovascular_Disease_Dataset.csv")
df.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# 2      1                 0       0
# 3      2                 2       1
# 4      3                 2       1

# %%
df.isnull().sum()
# Out:
# patientid            0
# age                  0
# gender               0
# chestpain            0
# restingBP            0
# serumcholestrol      0
# fastingbloodsugar    0
# restingrelectro      0
# maxheartrate         0
# exerciseangia        0
# oldpeak              0
# slope                0
# noofmajorvessels     0
# target               0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   patientid          1000 non-null   int64
#  1   age                1000 non-null   int64
#  2   gender             1000 non-null   int64
#  3   chestpain          1000 non-null   int64
#  4   restingBP          1000 non-null   int64
#  5   serumcholestrol    1000 non-null   int64
#  6   fastingbloodsugar  1000 non-null   int64
#  7   restingrelectro    1000 non-null   int64
#  8   maxheartrate       1000 non-null   int64
#  9   exerciseangia      1000 non-null   int64
#  10  oldpeak            1000 non-null   float64
#  11  slope              1000 non-null   int64
#  12  noofmajorvessels   1000 non-null   int64
#  13  target             1000 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 109.5 KB

# %%
df.describe()
# Out:
#           patientid         age       gender    chestpain    restingBP  \
# count  1.000000e+03  1000.00000  1000.000000  1000.000000  1000.000000
# mean   5.048704e+06    49.24200     0.765000     0.980000   151.747000
# std    2.895905e+06    17.86473     0.424211     0.953157    29.965228
# min    1.033680e+05    20.00000     0.000000     0.000000    94.000000
# 25%    2.536440e+06    34.00000     1.000000     0.000000   129.000000
# 50%    4.952508e+06    49.00000     1.000000     1.000000   147.000000
# 75%    7.681877e+06    64.25000     1.000000     2.000000   181.000000
# max    9.990855e+06    80.00000     1.000000     3.000000   200.000000
#
#        serumcholestrol  fastingbloodsugar  restingrelectro  maxheartrate  \
# count      1000.000000        1000.000000      1000.000000   1000.000000
# mean        311.447000           0.296000         0.748000    145.477000
# std         132.443801           0.456719         0.770123     34.190268
# min           0.000000           0.000000         0.000000     71.000000
# 25%         235.750000           0.000000         0.000000    119.750000
# 50%         318.000000           0.000000         1.000000    146.000000
# 75%         404.250000           1.000000         1.000000    175.000000
# max         602.000000           1.000000         2.000000    202.000000
#
#        exerciseangia      oldpeak        slope  noofmajorvessels       target
# count    1000.000000  1000.000000  1000.000000       1000.000000  1000.000000
# mean        0.498000     2.707700     1.540000          1.222000     0.580000
# std         0.500246     1.720753     1.003697          0.977585     0.493805
# min         0.000000     0.000000     0.000000          0.000000     0.000000
# 25%         0.000000     1.300000     1.000000          0.000000     0.000000
# 50%         0.000000     2.400000     2.000000          1.000000     1.000000
# 75%         1.000000     4.100000     2.000000          2.000000     1.000000
# max         1.000000     6.200000     3.000000          3.000000     1.000000

# %%
df['target'].value_counts()
# Out:
# target
# 1    580
# 0    420
# Name: count, dtype: int64

# %%
df = df.drop("patientid", axis=1)
df.head()
# Out:
#    age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 0   53       1          2        171                0                  0
# 1   40       1          0         94              229                  0
# 2   49       1          2        133              142                  0
# 3   43       1          0        138              295                  1
# 4   31       1          1        199                0                  0
#
#    restingrelectro  maxheartrate  exerciseangia  oldpeak  slope  \
# 0                1           147              0      5.3      3
# 1                1           115              0      3.7      1
# 2                0           202              1      5.0      1
# 3                1           153              0      3.2      2
# 4                2           136              0      5.3      3
#
#    noofmajorvessels  target
# 0                 3       1
# 1                 1       0
# 2                 0       0
# 3                 2       1
# 4                 2       1

# %% [markdown]
# EDA

# %%
df.columns
# Out:
# Index(['age', 'gender', 'chestpain', 'restingBP', 'serumcholestrol',
#        'fastingbloodsugar', 'restingrelectro', 'maxheartrate', 'exerciseangia',
#        'oldpeak', 'slope', 'noofmajorvessels', 'target'],
#       dtype='str')

# %%
sns.scatterplot(x='age', y='serumcholestrol', data=df)
# Out:
# <Axes: xlabel='age', ylabel='serumcholestrol'>

# %%
(df["serumcholestrol"]==0).sum()
# Out:
# np.int64(53)

# %%
sns.histplot(data=df, x='age', bins=30, kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(data=df,
            x="target",
            y="age")
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.boxplot(data=df,
            x="target",
            y="serumcholestrol")
# Out:
# <Axes: xlabel='target', ylabel='serumcholestrol'>

# %%
sns.countplot(data=df,
              x="chestpain",
              hue="target")
# Out:
# <Axes: xlabel='chestpain', ylabel='count'>

# %%
sns.countplot(data=df,
              x="gender",
              hue="target")
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(data=df,x="exerciseangia",hue="target")
# Out:
# <Axes: xlabel='exerciseangia', ylabel='count'>

# %%
plt.figure(figsize=(12,8))

sns.heatmap(df.corr(),
            annot=True,
            cmap="coolwarm")

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# DATA PREPROCESSING

# %%
df["serumcholestrol"] = df["serumcholestrol"].replace(0, np.nan)

# %%
x = df.drop("target", axis=1)
y = df["target"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (800, 12)
# (200, 12)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

# %%
X_train = pd.DataFrame(X_train, columns=x.columns)
X_test = pd.DataFrame(X_test, columns=x.columns)

# %%
X_train.head()
# Out:
#     age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 0  49.0     0.0        1.0      192.0            521.0                0.0
# 1  57.0     1.0        0.0      130.0            318.0                0.0
# 2  62.0     0.0        0.0      187.0            314.0                1.0
# 3  58.0     1.0        0.0      108.0            133.0                0.0
# 4  42.0     1.0        0.0      152.0            348.0                0.0
#
#    restingrelectro  maxheartrate  exerciseangia  oldpeak  slope  \
# 0              2.0         133.0            0.0      2.9    2.0
# 1              0.0         139.0            0.0      2.3    0.0
# 2              0.0         139.0            1.0      1.9    3.0
# 3              0.0         171.0            1.0      0.8    1.0
# 4              2.0         125.0            0.0      2.5    3.0
#
#    noofmajorvessels
# 0               2.0
# 1               1.0
# 2               2.0
# 3               2.0
# 4               1.0

# %%
numerical_cols = [
    "age",
    "restingBP",
    "serumcholestrol",
    "maxheartrate",
    "oldpeak"
]

categorical_cols = [
    "gender",
    "chestpain",
    "fastingbloodsugar",
    "restingrelectro",
    "exerciseangia",
    "slope",
    "noofmajorvessels"
]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train[numerical_cols] = scaler.fit_transform(X_train[numerical_cols])
X_test[numerical_cols] = scaler.transform(X_test[numerical_cols])

# %%
X_train.head()
# Out:
#         age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 0  0.024295     0.0        1.0   1.320889         1.734882                0.0
# 1  0.472386     1.0        0.0  -0.738588        -0.121511                0.0
# 2  0.752443     0.0        0.0   1.154802        -0.158091                1.0
# 3  0.528397     1.0        0.0  -1.469370        -1.813299                0.0
# 4 -0.367785     1.0        0.0  -0.007806         0.152832                0.0
#
#    restingrelectro  maxheartrate  exerciseangia   oldpeak  slope  \
# 0              2.0     -0.394077            0.0  0.110690    2.0
# 1              0.0     -0.215019            0.0 -0.236345    0.0
# 2              0.0     -0.215019            1.0 -0.467701    3.0
# 3              0.0      0.739958            1.0 -1.103932    1.0
# 4              2.0     -0.632821            0.0 -0.120667    3.0
#
#    noofmajorvessels
# 0               2.0
# 1               1.0
# 2               2.0
# 3               2.0
# 4               1.0

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_train, y_train)
# Out:
# 0.97125

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.9600

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95        83
#            1       0.96      0.97      0.97       117
#
#     accuracy                           0.96       200
#    macro avg       0.96      0.96      0.96       200
# weighted avg       0.96      0.96      0.96       200

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
plt.show()

# %%
df["target"].value_counts()
# Out:
# target
# 1    580
# 0    420
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1000, 13)
